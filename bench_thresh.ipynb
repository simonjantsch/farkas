# %%
#import nbimporter
import MDP as mdp
import MDP_gurobi as mdp_gurobi
from ttictoc import TicToc
import numpy as np
# Out:
# Importing Jupyter notebook from MDP.ipynb
# Importing Jupyter notebook from helpers.ipynb
# Importing Jupyter notebook from MDP_gurobi.ipynb

# %%
csv_file_path = "csv/csma/csma-thresh-" + str(2) + "-" + str(4) + ".csv"
        
model_path = "mdp_benchmarks/csma_files/csma-" + str(2) + "-" + str(4)
N,A,P,initial,to_target,enabled_actions = mdp.load_model(model_path,"all_delivered")

# %%
for i in [2]: #2,3
    for j in [4]: #2,4,6
#        csv_file_path = "csv/csma/csma-thresh-" + str(i) + "-" + str(j) + ".csv"
#        
#        model_path = "mdp_benchmarks/csma_files/csma-" + str(i) + "-" + str(j)
#        N,A,P,initial,to_target,enabled_actions = mdp.load_model(model_path,"all_delivered")
        
        t = TicToc()

        ## time of computing Pr_max 
        t.tic()
        feas,prmax = mdp_gurobi.prmax_lp(N,A,initial,P,to_target,enabled_actions)
        t.toc()
        print(prmax[initial])
        print(prmax)
 
        with open(csv_file_path, "w") as csv_file:
            csv_file.write("computing prmax: " + str(t.elapsed) + "\n")
            csv_file.write("threshold,time\n")

        thr = 0.1
        opt = np.zeros(N*A)

        while thr <= 1:
            t.tic()
            res = mdp_gurobi.prmax_geq_thr(N,A,initial,P,to_target,enabled_actions,thr)
            t.toc()
            break
            with open(csv_file_path,"a") as csv_file:
                csv_file.write(str(thr) + " " + str(res) + " " + str(t.elapsed) + "\n")
            
            thr += 0.2
# Out:
# Academic license - for non-commercial use only
# Changed value of parameter NumericFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Optimize a model with 7981 rows, 7951 columns and 18560 nonzeros
# Coefficient statistics:
#   Matrix range     [6e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 7942 rows and 7912 columns
# Presolve time: 0.06s
# Presolved: 39 rows, 39 columns, 104 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.8475179e+03   3.499563e+00   0.000000e+00      0s
#       39    7.9510000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.10 seconds
# Optimal objective  7.951000000e+03
# 1.0
# [1. 1. 1. ... 1. 1. 1.]
# Changed value of parameter NumericFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Changed value of parameter Presolve to 0
#    Prev: -1  Min: -1  Max: 2  Default: -1
# ...
